# %%
from __future__ import print_function

import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,TensorBoard,ReduceLROnPlateau

from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.activations import relu
from tensorflow.keras.regularizers import l2
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K
# from tensorflow.keras.datasets import mnist, cifar10
import tensorflow_addons as tfa

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from scipy.io import loadmat 
import mat73
from datetime import datetime
import ipynbname
import time


from packaging import version
print("Packages Loaded")
# Out:
# Packages Loaded

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
import wandb
from wandb.keras import WandbCallback

wandb.init(project="my-test-project", 
           entity="ibksolar",
           name="DenseLayers_trial",
           config = {
                          "learning_rate": "NA",
                          "epochs": 50,
                          "batch_size": 512,
                          "nodes": 2048,
                          "row_length":21,
                          #"base_path":base_path,
                          "num_classes":22,

}
          )
# Out:
# wandb: Currently logged in as: ibksolar (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.11 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/ibksolar/my-test-project/runs/3oc0qf8j" target="_blank">DenseLayers_trial</a></strong> to <a href="https://wandb.ai/ibksolar/my-test-project" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/ibksolar/my-test-project/runs/3oc0qf8j?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
# Load data
# raw_data1 = loadmat('new_echo_cnn_in_out_jstarrs2021_first_try/echo_cnn_in_out_jstars1.mat')
# raw_data1 = loadmat('echo_cnn_in_out_GOOD_layers/new_echo_cnn_in_out_jstars1.mat') 'findpeaks_layers/new_echo_cnn_in_out_jstars1.mat'

raw_data1 = loadmat('../../../Python_Env/final_layers_rowblock15_21/filtered_image/new_echo_cnn_in_out_jstars1.mat')
raw_data2 = loadmat('../../../Python_Env/final_layers_rowblock15_21/filtered_image/new_echo_cnn_in_out_jstars2.mat')
raw_data3 = loadmat('../../../Python_Env/final_layers_rowblock15_21/filtered_image/new_echo_cnn_in_out_jstars3.mat')
# raw_data4 = loadmat('findpeaks_layers_rowblock20/new_echo_cnn_in_out_jstars4.mat')

d1 = raw_data1['echo_cnn1']
t1 = raw_data1['echo_target1']
i1 = raw_data1['echo_idx1']

d2 = raw_data2['echo_cnn2']
t2 = raw_data2['echo_target2']
i2 = raw_data2['echo_idx2']

d3 = raw_data3['echo_cnn3']
t3 = raw_data3['echo_target3']
i3 = raw_data3['echo_idx3']

# d4 = raw_data4['echo_cnn4']
# t4 = raw_data4['echo_target4']
# i4 = raw_data4['echo_idx4']

all_data = np.concatenate( (d1,d2,d3),axis = 0 )
all_target = np.concatenate( (t1,t2,t3),axis = 0 )
all_idx = np.concatenate( (i1,i2,i3),axis = 0 )

# Set all nan in the data to zero
nan_idx = np.isnan(all_data).any(axis =-1)
all_target[nan_idx] = 0
all_data[ np.isnan(all_data) ]= 0

# %%
# base_path = '..\\..\\all_block_data\Dec_Train_block_len_21_011121_2331'
base_path = '../all_block_data/Old_data/Dec_Train_block_len_21_131121_2213'

# Confirm path is right...
print(f'{os.path.isdir(base_path)}')
# Out:
# True

# %%
load_new_data = False

if load_new_data:    
    raw_data1 = mat73.loadmat(base_path + '/echo_cnn_in_out_jstars.mat')
    all_data = raw_data1['echo_cnn_input']#*255
    all_target = raw_data1['echo_cnn_target']

# %%
row_length = 21 # CHANGE HERE <==
col_length = 15

# Check that the dimension of data is correct
if all_data.shape[1] == row_length*col_length:
    print('Dimensions match')
else:
    print(f' Row block length:{row_length} and col length:{col_length} does not match Data dimension:{all_data.shape[1]}')
# Out:
# Dimensions match

# %%
max_class = row_length 

# Highest class is mapped to row_length+1
all_target[all_target == max_class+1 ] = 0


shuffle = 1
if shuffle:
    random.Random(1337).shuffle(all_data)
    random.Random(1337).shuffle(all_target)
    random.Random(1337).shuffle(all_idx)

## Prep data
train_size = int(np.floor(0.75*len(all_target)));
test_size = int(np.round( 0.15* all_data.shape[0] ))
val_size = all_data.shape[0] -train_size - test_size


x_train = all_data[0:train_size,:]

x_test = all_data[train_size:train_size+test_size,:]

x_val = all_data[-val_size:,:]

y_train = all_target[:train_size]
y_test  = all_target[train_size:train_size+test_size]
y_val = all_target[-val_size:]

var_input_shape = x_train.shape[1:] # 240 columns
num_classes = max_class+1 # layers

# Convert labels to categorical orthonormal vectors
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test  = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
#config = wandb.config
config = {
          "learning_rate": "NA",
          #"epochs": 50,
          #"batch_size": 512,
          "nodes": 2048,
          "row_length":21,
          #"base_path":base_path,
          "num_classes":22,
}

config['batch_size'] = 64
config['epochs'] = 20

# %%
import GPUtil
from threading import Thread
import time

class Monitor(Thread):
    def __init__(self, delay, HardStop= False):
        super(Monitor, self).__init__()
        self.stopped = False
        self.delay = delay # Time between calls to GPUtil
        self.HardStop = HardStop
        self.start()

    def run(self):
        while not self.stopped and not self.HardStop :
            GPUtil.showUtilization()
            time.sleep(self.delay)
             

    def stop(self):
        self.stopped = True

# %%
# Define Sequential model with 3 layers

model = tf.keras.Sequential(
    [
        layers.Dense(config['nodes'], activation="relu", name="layer1"),
        layers.Dense(config['nodes'], activation="relu", name="layer2"),
        layers.Dense(config['nodes'], activation="relu", name="layer3"),
        layers.Dense(config['num_classes'],activation="softmax", name="Final_layer"),
    ]
)

opt = tf.keras.optimizers.RMSprop(
    learning_rate=0.001,
    rho=0.999,
    momentum=0.999,
    epsilon=1e-07,
    #centered=True,
    name="RMSprop")

top_K = 3
model.compile( "rmsprop", loss= 'categorical_crossentropy', metrics=['accuracy',tf.keras.metrics.TopKCategoricalAccuracy(top_K, name="top-3-accuracy")])  #label_smoothing=0.05, tf.keras.losses.KLDivergence()
#optimizer = opt,"rmsprop"


# Callbacks
#model_save_path = os.path.join(os.path.dirname(os.getcwd()), r'all_block_data\PulsedTrainTest')
#logs = model_save_path+'/'+ipynbname.name()+f"/{config['start_time']}_logs/" 
callbacks = [
    #ModelCheckpoint(base_path2+'/'+ipynbname.name()+f"/{start_time}_Checkpoint.h5", save_best_only=True, monitor="val_loss"),
    ReduceLROnPlateau(monitor="val_loss", factor=0.05, patience=15, min_lr=0.0001),
    #EarlyStopping(monitor="val_loss", patience=60, verbose=1),
    #TensorBoard(log_dir = logs,histogram_freq = 1,profile_batch = '500,520'),
    #WandbCallback()
]

Report = {} # This reports time and GPU usage for each batch size

for curr_batch_size in [128, 512, 1024]:
    
    # Instantiate monitor with a 10-second delay between updates
    monitor = Monitor(10)
    
    config['start_time'] = datetime.strftime( datetime.now(),'%d_%B_%y_%H%M')
    print(f'Training start time:{config["start_time"]}')
    
    start_time = time.time()
    history = model.fit(x_train, y_train,
              epochs= config['epochs'], 
              batch_size= curr_batch_size, 
              validation_data=(x_test, y_test),
             callbacks=callbacks) #mcp_save, callbacks=[reduce_lr_loss]

    config['end_time'] = datetime.strftime( datetime.now(),'%d_%B_%y_%H%M')
    stop_time= time.time()
    print(f'Training End time:{config["end_time"]}')
    
    # Update Record
    
    Report[curr_batch_size] = ( os.environ['COMPUTERNAME'],config['start_time'],config['end_time'],int(stop_time-start_time), monitor )
    
    # Close monitor
    monitor.stop()
# Out:
# Training start time:11_March_22_1604
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  3% |
# Epoch 1/20
#  1471/12272 [==>...........................] - ETA: 54s - loss: 2.0514 - accuracy: 0.2676 - top-3-accuracy: 0.6097| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  3500/12272 [=======>......................] - ETA: 43s - loss: 1.8139 - accuracy: 0.3344 - top-3-accuracy: 0.7084| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  5509/12272 [============>.................] - ETA: 33s - loss: 1.6931 - accuracy: 0.3715 - top-3-accuracy: 0.7525| ID | GPU | MEM |
# ------------------
# |  0 | 44% | 21% |
#  7522/12272 [=================>............] - ETA: 23s - loss: 1.6129 - accuracy: 0.3972 - top-3-accuracy: 0.7795| ID | GPU | MEM |
# ------------------
# |  0 | 41% | 21% |
#  9542/12272 [======================>.......] - ETA: 13s - loss: 1.5545 - accuracy: 0.4166 - top-3-accuracy: 0.7980| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 11557/12272 [===========================>..] - ETA: 3s - loss: 1.5100 - accuracy: 0.4313 - top-3-accuracy: 0.8112| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.4967 - accuracy: 0.4359 - top-3-accuracy: 0.8151 - val_loss: 1.5184 - val_accuracy: 0.4605 - val_top-3-accuracy: 0.8351
# Epoch 2/20
#   511/12272 [>.............................] - ETA: 58s - loss: 1.2827 - accuracy: 0.5061 - top-3-accuracy: 0.8780| ID | GPU | MEM
# ------------------
# |  0 | 43% | 21% |
#  2530/12272 [=====>........................] - ETA: 48s - loss: 1.2678 - accuracy: 0.5127 - top-3-accuracy: 0.8811| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  4544/12272 [==========>...................] - ETA: 38s - loss: 1.2566 - accuracy: 0.5168 - top-3-accuracy: 0.8833| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  6554/12272 [===============>..............] - ETA: 28s - loss: 1.2479 - accuracy: 0.5209 - top-3-accuracy: 0.8847| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  8567/12272 [===================>..........] - ETA: 18s - loss: 1.2394 - accuracy: 0.5242 - top-3-accuracy: 0.8863| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 10571/12272 [========================>.....] - ETA: 8s - loss: 1.2327 - accuracy: 0.5272 - top-3-accuracy: 0.8876| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12263/12272 [============================>.] - ETA: 0s - loss: 1.2276 - accuracy: 0.5293 - top-3-accuracy: 0.8885| ID | GPU | MEM |
# ------------------
# |  0 | 27% | 21% |
# 12272/12272 [==============================] - 65s 5ms/step - loss: 1.2276 - accuracy: 0.5293 - top-3-accuracy: 0.8885 - val_loss: 1.3613 - val_accuracy: 0.5427 - val_top-3-accuracy: 0.8877
# Epoch 3/20
#  1561/12272 [==>...........................] - ETA: 54s - loss: 1.1919 - accuracy: 0.5451 - top-3-accuracy: 0.8956| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  3518/12272 [=======>......................] - ETA: 44s - loss: 1.1858 - accuracy: 0.5470 - top-3-accuracy: 0.8966| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  5486/12272 [============>.................] - ETA: 34s - loss: 1.1829 - accuracy: 0.5483 - top-3-accuracy: 0.8972| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  7483/12272 [=================>............] - ETA: 24s - loss: 1.1800 - accuracy: 0.5494 - top-3-accuracy: 0.8976| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  9466/12272 [======================>.......] - ETA: 14s - loss: 1.1774 - accuracy: 0.5504 - top-3-accuracy: 0.8979| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 11446/12272 [==========================>...] - ETA: 4s - loss: 1.1739 - accuracy: 0.5515 - top-3-accuracy: 0.8987| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.1731 - accuracy: 0.5519 - top-3-accuracy: 0.8987 - val_loss: 1.3301 - val_accuracy: 0.5630 - val_top-3-accuracy: 0.8916
# Epoch 4/20
#   475/12272 [>.............................] - ETA: 59s - loss: 1.1526 - accuracy: 0.5622 - top-3-accuracy: 0.9030| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  2469/12272 [=====>........................] - ETA: 49s - loss: 1.1552 - accuracy: 0.5596 - top-3-accuracy: 0.9020| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  4453/12272 [=========>....................] - ETA: 39s - loss: 1.1521 - accuracy: 0.5606 - top-3-accuracy: 0.9022| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  6429/12272 [==============>...............] - ETA: 29s - loss: 1.1509 - accuracy: 0.5610 - top-3-accuracy: 0.9026| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  8397/12272 [===================>..........] - ETA: 19s - loss: 1.1489 - accuracy: 0.5615 - top-3-accuracy: 0.9031| ID | GPU | MEM |
# ------------------
# |  0 | 41% | 21% |
# 10356/12272 [========================>.....] - ETA: 9s - loss: 1.1482 - accuracy: 0.5618 - top-3-accuracy: 0.9033| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12271/12272 [============================>.] - ETA: 0s - loss: 1.1471 - accuracy: 0.5625 - top-3-accuracy: 0.9035| ID | GPU | MEM |
# ------------------
# |  0 | 28% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.1471 - accuracy: 0.5625 - top-3-accuracy: 0.9035 - val_loss: 1.3350 - val_accuracy: 0.5625 - val_top-3-accuracy: 0.8923
# Epoch 5/20
#  1310/12272 [==>...........................] - ETA: 56s - loss: 1.1358 - accuracy: 0.5660 - top-3-accuracy: 0.9063| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  3294/12272 [=======>......................] - ETA: 45s - loss: 1.1381 - accuracy: 0.5663 - top-3-accuracy: 0.9055| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  5272/12272 [===========>..................] - ETA: 35s - loss: 1.1343 - accuracy: 0.5678 - top-3-accuracy: 0.9062| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  7247/12272 [================>.............] - ETA: 25s - loss: 1.1338 - accuracy: 0.5679 - top-3-accuracy: 0.9061| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  9227/12272 [=====================>........] - ETA: 15s - loss: 1.1331 - accuracy: 0.5681 - top-3-accuracy: 0.9063| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 11203/12272 [==========================>...] - ETA: 5s - loss: 1.1327 - accuracy: 0.5683 - top-3-accuracy: 0.9064| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.1329 - accuracy: 0.5685 - top-3-accuracy: 0.9064 - val_loss: 1.3302 - val_accuracy: 0.5500 - val_top-3-accuracy: 0.8865
# Epoch 6/20
#   202/12272 [..............................] - ETA: 1:02 - loss: 1.1228 - accuracy: 0.5697 - top-3-accuracy: 0.9059| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  2160/12272 [====>.........................] - ETA: 51s - loss: 1.1309 - accuracy: 0.5704 - top-3-accuracy: 0.9060| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  4109/12272 [=========>....................] - ETA: 41s - loss: 1.1300 - accuracy: 0.5711 - top-3-accuracy: 0.9066| ID | GPU | MEM |
# ------------------
# |  0 | 41% | 21% |
#  6078/12272 [=============>................] - ETA: 31s - loss: 1.1278 - accuracy: 0.5719 - top-3-accuracy: 0.9072| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  8053/12272 [==================>...........] - ETA: 21s - loss: 1.1278 - accuracy: 0.5719 - top-3-accuracy: 0.9072| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 10042/12272 [=======================>......] - ETA: 11s - loss: 1.1276 - accuracy: 0.5721 - top-3-accuracy: 0.9071| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 12029/12272 [============================>.] - ETA: 1s - loss: 1.1267 - accuracy: 0.5723 - top-3-accuracy: 0.9073| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.1265 - accuracy: 0.5723 - top-3-accuracy: 0.9073 - val_loss: 1.3818 - val_accuracy: 0.5558 - val_top-3-accuracy: 0.8868
# Epoch 7/20
#  1058/12272 [=>............................] - ETA: 56s - loss: 1.1233 - accuracy: 0.5733 - top-3-accuracy: 0.9073| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  3035/12272 [======>.......................] - ETA: 47s - loss: 1.1228 - accuracy: 0.5733 - top-3-accuracy: 0.9085| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  4985/12272 [===========>..................] - ETA: 37s - loss: 1.1220 - accuracy: 0.5740 - top-3-accuracy: 0.9084| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  6969/12272 [================>.............] - ETA: 27s - loss: 1.1229 - accuracy: 0.5739 - top-3-accuracy: 0.9084| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  8933/12272 [====================>.........] - ETA: 17s - loss: 1.1222 - accuracy: 0.5738 - top-3-accuracy: 0.9084| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 10916/12272 [=========================>....] - ETA: 6s - loss: 1.1220 - accuracy: 0.5739 - top-3-accuracy: 0.9084| ID | GPU | MEM |
# ------------------
# |  0 | 39% | 21% |
# 12264/12272 [============================>.] - ETA: 0s - loss: 1.1215 - accuracy: 0.5742 - top-3-accuracy: 0.9085| ID | GPU | MEM |
# ------------------
# |  0 | 27% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.1215 - accuracy: 0.5742 - top-3-accuracy: 0.9085 - val_loss: 1.6532 - val_accuracy: 0.4788 - val_top-3-accuracy: 0.8402
# Epoch 8/20
#  1873/12272 [===>..........................] - ETA: 53s - loss: 1.1184 - accuracy: 0.5753 - top-3-accuracy: 0.9088| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  3847/12272 [========>.....................] - ETA: 43s - loss: 1.1177 - accuracy: 0.5760 - top-3-accuracy: 0.9089| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  5833/12272 [=============>................] - ETA: 32s - loss: 1.1162 - accuracy: 0.5760 - top-3-accuracy: 0.9095| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  7795/12272 [==================>...........] - ETA: 22s - loss: 1.1159 - accuracy: 0.5762 - top-3-accuracy: 0.9095| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  9763/12272 [======================>.......] - ETA: 12s - loss: 1.1159 - accuracy: 0.5761 - top-3-accuracy: 0.9095| ID | GPU | MEM |
# ------------------
# |  0 | 38% | 21% |
# 11735/12272 [===========================>..] - ETA: 2s - loss: 1.1151 - accuracy: 0.5765 - top-3-accuracy: 0.9097| ID | GPU | MEM |
# ------------------
# |  0 | 40% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.1152 - accuracy: 0.5764 - top-3-accuracy: 0.9097 - val_loss: 1.4558 - val_accuracy: 0.5320 - val_top-3-accuracy: 0.8767
# Epoch 9/20
#   734/12272 [>.............................] - ETA: 1:00 - loss: 1.1112 - accuracy: 0.5756 - top-3-accuracy: 0.9106| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  2682/12272 [=====>........................] - ETA: 49s - loss: 1.1151 - accuracy: 0.5775 - top-3-accuracy: 0.9100| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  4632/12272 [==========>...................] - ETA: 39s - loss: 1.1145 - accuracy: 0.5778 - top-3-accuracy: 0.9101| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  6607/12272 [===============>..............] - ETA: 29s - loss: 1.1152 - accuracy: 0.5779 - top-3-accuracy: 0.9101| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  8577/12272 [===================>..........] - ETA: 18s - loss: 1.1159 - accuracy: 0.5773 - top-3-accuracy: 0.9100| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 10540/12272 [========================>.....] - ETA: 8s - loss: 1.1149 - accuracy: 0.5778 - top-3-accuracy: 0.9102| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12266/12272 [============================>.] - ETA: 0s - loss: 1.1150 - accuracy: 0.5779 - top-3-accuracy: 0.9102| ID | GPU | MEM |
# ------------------
# |  0 | 27% | 21% |
# 12272/12272 [==============================] - 67s 5ms/step - loss: 1.1150 - accuracy: 0.5779 - top-3-accuracy: 0.9102 - val_loss: 1.4151 - val_accuracy: 0.5213 - val_top-3-accuracy: 0.8797
# Epoch 10/20
#  1499/12272 [==>...........................] - ETA: 55s - loss: 1.1160 - accuracy: 0.5768 - top-3-accuracy: 0.9103| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  3479/12272 [=======>......................] - ETA: 44s - loss: 1.1146 - accuracy: 0.5774 - top-3-accuracy: 0.9106| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  5452/12272 [============>.................] - ETA: 34s - loss: 1.1149 - accuracy: 0.5773 - top-3-accuracy: 0.9103| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  7434/12272 [=================>............] - ETA: 24s - loss: 1.1141 - accuracy: 0.5778 - top-3-accuracy: 0.9102| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  9400/12272 [=====================>........] - ETA: 14s - loss: 1.1147 - accuracy: 0.5778 - top-3-accuracy: 0.9101| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 11378/12272 [==========================>...] - ETA: 4s - loss: 1.1145 - accuracy: 0.5781 - top-3-accuracy: 0.9100| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.1143 - accuracy: 0.5782 - top-3-accuracy: 0.9101 - val_loss: 1.3790 - val_accuracy: 0.5789 - val_top-3-accuracy: 0.8985
# Epoch 11/20
#   383/12272 [..............................] - ETA: 1:01 - loss: 1.1146 - accuracy: 0.5752 - top-3-accuracy: 0.9091| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  2348/12272 [====>.........................] - ETA: 50s - loss: 1.1135 - accuracy: 0.5787 - top-3-accuracy: 0.9102| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  4320/12272 [=========>....................] - ETA: 40s - loss: 1.1113 - accuracy: 0.5799 - top-3-accuracy: 0.9105| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  6272/12272 [==============>...............] - ETA: 30s - loss: 1.1115 - accuracy: 0.5796 - top-3-accuracy: 0.9105| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  8239/12272 [===================>..........] - ETA: 20s - loss: 1.1101 - accuracy: 0.5801 - top-3-accuracy: 0.9106| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 10209/12272 [=======================>......] - ETA: 10s - loss: 1.1084 - accuracy: 0.5804 - top-3-accuracy: 0.9107| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12155/12272 [============================>.] - ETA: 0s - loss: 1.1076 - accuracy: 0.5805 - top-3-accuracy: 0.9109| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.1077 - accuracy: 0.5804 - top-3-accuracy: 0.9109 - val_loss: 1.5573 - val_accuracy: 0.5049 - val_top-3-accuracy: 0.8597
# Epoch 12/20
#  1152/12272 [=>............................] - ETA: 57s - loss: 1.1000 - accuracy: 0.5824 - top-3-accuracy: 0.9125| ID | GPU | MEM |
# ------------------
# |  0 | 41% | 21% |
#  3100/12272 [======>.......................] - ETA: 47s - loss: 1.1004 - accuracy: 0.5830 - top-3-accuracy: 0.9118| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  5048/12272 [===========>..................] - ETA: 37s - loss: 1.1011 - accuracy: 0.5824 - top-3-accuracy: 0.9117| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  6996/12272 [================>.............] - ETA: 27s - loss: 1.1003 - accuracy: 0.5827 - top-3-accuracy: 0.9119| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  8945/12272 [====================>.........] - ETA: 17s - loss: 1.0995 - accuracy: 0.5832 - top-3-accuracy: 0.9121| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 10910/12272 [=========================>....] - ETA: 7s - loss: 1.0997 - accuracy: 0.5833 - top-3-accuracy: 0.9121| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12269/12272 [============================>.] - ETA: 0s - loss: 1.0995 - accuracy: 0.5832 - top-3-accuracy: 0.9122| ID | GPU | MEM |
# ------------------
# |  0 | 27% | 21% |
# 12272/12272 [==============================] - 67s 5ms/step - loss: 1.0995 - accuracy: 0.5832 - top-3-accuracy: 0.9122 - val_loss: 1.4092 - val_accuracy: 0.5701 - val_top-3-accuracy: 0.8920
# Epoch 13/20
#  1860/12272 [===>..........................] - ETA: 53s - loss: 1.0947 - accuracy: 0.5833 - top-3-accuracy: 0.9127| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  3832/12272 [========>.....................] - ETA: 43s - loss: 1.0949 - accuracy: 0.5841 - top-3-accuracy: 0.9129| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  5810/12272 [=============>................] - ETA: 32s - loss: 1.0951 - accuracy: 0.5840 - top-3-accuracy: 0.9127| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  7775/12272 [==================>...........] - ETA: 22s - loss: 1.0956 - accuracy: 0.5843 - top-3-accuracy: 0.9131| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  9726/12272 [======================>.......] - ETA: 13s - loss: 1.0955 - accuracy: 0.5844 - top-3-accuracy: 0.9133| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 11698/12272 [===========================>..] - ETA: 2s - loss: 1.0959 - accuracy: 0.5841 - top-3-accuracy: 0.9134| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.0959 - accuracy: 0.5840 - top-3-accuracy: 0.9133 - val_loss: 1.4675 - val_accuracy: 0.5785 - val_top-3-accuracy: 0.8961
# Epoch 14/20
#   709/12272 [>.............................] - ETA: 58s - loss: 1.0956 - accuracy: 0.5828 - top-3-accuracy: 0.9127| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  2676/12272 [=====>........................] - ETA: 48s - loss: 1.0969 - accuracy: 0.5840 - top-3-accuracy: 0.9128| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  4650/12272 [==========>...................] - ETA: 38s - loss: 1.0951 - accuracy: 0.5839 - top-3-accuracy: 0.9130| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  6620/12272 [===============>..............] - ETA: 28s - loss: 1.0968 - accuracy: 0.5835 - top-3-accuracy: 0.9129| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  8595/12272 [====================>.........] - ETA: 18s - loss: 1.0974 - accuracy: 0.5834 - top-3-accuracy: 0.9129| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 10572/12272 [========================>.....] - ETA: 8s - loss: 1.0974 - accuracy: 0.5834 - top-3-accuracy: 0.9129| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 12264/12272 [============================>.] - ETA: 0s - loss: 1.0971 - accuracy: 0.5836 - top-3-accuracy: 0.9129| ID | GPU | MEM |
# ------------------
# |  0 | 27% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.0972 - accuracy: 0.5836 - top-3-accuracy: 0.9129 - val_loss: 1.4438 - val_accuracy: 0.5716 - val_top-3-accuracy: 0.8926
# Epoch 15/20
#  1526/12272 [==>...........................] - ETA: 55s - loss: 1.0959 - accuracy: 0.5845 - top-3-accuracy: 0.9129| ID | GPU | MEM |
# ------------------
# |  0 | 41% | 21% |
#  3470/12272 [=======>......................] - ETA: 45s - loss: 1.0967 - accuracy: 0.5848 - top-3-accuracy: 0.9126| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  5434/12272 [============>.................] - ETA: 35s - loss: 1.0982 - accuracy: 0.5846 - top-3-accuracy: 0.9124| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  7409/12272 [=================>............] - ETA: 24s - loss: 1.0977 - accuracy: 0.5850 - top-3-accuracy: 0.9125| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  9383/12272 [=====================>........] - ETA: 14s - loss: 1.0985 - accuracy: 0.5847 - top-3-accuracy: 0.9124| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 11371/12272 [==========================>...] - ETA: 4s - loss: 1.0987 - accuracy: 0.5846 - top-3-accuracy: 0.9123| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.0986 - accuracy: 0.5848 - top-3-accuracy: 0.9125 - val_loss: 1.4395 - val_accuracy: 0.5591 - val_top-3-accuracy: 0.8891
# Epoch 16/20
#   395/12272 [..............................] - ETA: 1:00 - loss: 1.0998 - accuracy: 0.5836 - top-3-accuracy: 0.9131| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  2371/12272 [====>.........................] - ETA: 50s - loss: 1.1028 - accuracy: 0.5831 - top-3-accuracy: 0.9121| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  4339/12272 [=========>....................] - ETA: 40s - loss: 1.1006 - accuracy: 0.5840 - top-3-accuracy: 0.9121| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  6299/12272 [==============>...............] - ETA: 30s - loss: 1.1000 - accuracy: 0.5841 - top-3-accuracy: 0.9120| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  8260/12272 [===================>..........] - ETA: 20s - loss: 1.0986 - accuracy: 0.5846 - top-3-accuracy: 0.9122| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 10231/12272 [========================>.....] - ETA: 10s - loss: 1.0976 - accuracy: 0.5850 - top-3-accuracy: 0.9124| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12207/12272 [============================>.] - ETA: 0s - loss: 1.0967 - accuracy: 0.5854 - top-3-accuracy: 0.9125| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.0967 - accuracy: 0.5854 - top-3-accuracy: 0.9125 - val_loss: 1.4997 - val_accuracy: 0.5325 - val_top-3-accuracy: 0.8782
# Epoch 17/20
#  1207/12272 [=>............................] - ETA: 56s - loss: 1.0971 - accuracy: 0.5887 - top-3-accuracy: 0.9128| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  3179/12272 [======>.......................] - ETA: 46s - loss: 1.0962 - accuracy: 0.5867 - top-3-accuracy: 0.9127| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  5159/12272 [===========>..................] - ETA: 36s - loss: 1.0966 - accuracy: 0.5869 - top-3-accuracy: 0.9130| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  7125/12272 [================>.............] - ETA: 26s - loss: 1.0962 - accuracy: 0.5866 - top-3-accuracy: 0.9131| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  9086/12272 [=====================>........] - ETA: 16s - loss: 1.0960 - accuracy: 0.5867 - top-3-accuracy: 0.9131| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 11042/12272 [=========================>....] - ETA: 6s - loss: 1.0954 - accuracy: 0.5868 - top-3-accuracy: 0.9131| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.0959 - accuracy: 0.5866 - top-3-accuracy: 0.9130 - val_loss: 1.4098 - val_accuracy: 0.5740 - val_top-3-accuracy: 0.8930
# Epoch 18/20
#    51/12272 [..............................] - ETA: 1:04 - loss: 1.0970 - accuracy: 0.5767 - top-3-accuracy: 0.9138| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  2004/12272 [===>..........................] - ETA: 52s - loss: 1.0926 - accuracy: 0.5863 - top-3-accuracy: 0.9133| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  3963/12272 [========>.....................] - ETA: 42s - loss: 1.0922 - accuracy: 0.5878 - top-3-accuracy: 0.9133| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  5941/12272 [=============>................] - ETA: 32s - loss: 1.0951 - accuracy: 0.5876 - top-3-accuracy: 0.9132| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  7915/12272 [==================>...........] - ETA: 22s - loss: 1.0963 - accuracy: 0.5871 - top-3-accuracy: 0.9132| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  9890/12272 [=======================>......] - ETA: 12s - loss: 1.0959 - accuracy: 0.5869 - top-3-accuracy: 0.9132| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 11857/12272 [===========================>..] - ETA: 2s - loss: 1.0952 - accuracy: 0.5873 - top-3-accuracy: 0.9133| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 1.0948 - accuracy: 0.5874 - top-3-accuracy: 0.9134 - val_loss: 1.5715 - val_accuracy: 0.5585 - val_top-3-accuracy: 0.8918
# Epoch 19/20
#   868/12272 [=>............................] - ETA: 58s - loss: 0.9971 - accuracy: 0.6203 - top-3-accuracy: 0.9260| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  2827/12272 [=====>........................] - ETA: 48s - loss: 0.9937 - accuracy: 0.6217 - top-3-accuracy: 0.9269| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  4795/12272 [==========>...................] - ETA: 38s - loss: 0.9929 - accuracy: 0.6219 - top-3-accuracy: 0.9272| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  6770/12272 [===============>..............] - ETA: 28s - loss: 0.9938 - accuracy: 0.6226 - top-3-accuracy: 0.9273| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  8746/12272 [====================>.........] - ETA: 17s - loss: 0.9918 - accuracy: 0.6233 - top-3-accuracy: 0.9274| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 10721/12272 [=========================>....] - ETA: 7s - loss: 0.9915 - accuracy: 0.6233 - top-3-accuracy: 0.9275| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 12264/12272 [============================>.] - ETA: 0s - loss: 0.9912 - accuracy: 0.6236 - top-3-accuracy: 0.9275| ID | GPU | MEM |
# ------------------
# |  0 | 28% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 0.9912 - accuracy: 0.6235 - top-3-accuracy: 0.9275 - val_loss: 1.4600 - val_accuracy: 0.6005 - val_top-3-accuracy: 0.9047
# Epoch 20/20
#  1708/12272 [===>..........................] - ETA: 53s - loss: 0.9906 - accuracy: 0.6246 - top-3-accuracy: 0.9281| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  3674/12272 [=======>......................] - ETA: 43s - loss: 0.9877 - accuracy: 0.6248 - top-3-accuracy: 0.9282| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  5654/12272 [============>.................] - ETA: 33s - loss: 0.9861 - accuracy: 0.6245 - top-3-accuracy: 0.9279| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
#  7631/12272 [=================>............] - ETA: 23s - loss: 0.9860 - accuracy: 0.6246 - top-3-accuracy: 0.9282| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
#  9606/12272 [======================>.......] - ETA: 13s - loss: 0.9847 - accuracy: 0.6250 - top-3-accuracy: 0.9284| ID | GPU | MEM |
# ------------------
# |  0 | 43% | 21% |
# 11575/12272 [===========================>..] - ETA: 3s - loss: 0.9841 - accuracy: 0.6253 - top-3-accuracy: 0.9285| ID | GPU | MEM |
# ------------------
# |  0 | 42% | 21% |
# 12272/12272 [==============================] - 66s 5ms/step - loss: 0.9845 - accuracy: 0.6255 - top-3-accuracy: 0.9285 - val_loss: 1.4796 - val_accuracy: 0.5981 - val_top-3-accuracy: 0.9044
# Training End time:11_March_22_1626
# Training start time:11_March_22_1626
# | ID | GPU | MEM |
# ------------------
# |  0 | 29% | 21% |
# Epoch 1/20
# 1452/3068 [=============>................] - ETA: 8s - loss: 0.9728 - accuracy: 0.6279 - top-3-accuracy: 0.9294| ID | GPU | MEM |
# ------------------
# |  0 | 47% | 37% |
# 3068/3068 [==============================] - ETA: 0s - loss: 0.9725 - accuracy: 0.6281 - top-3-accuracy: 0.9296| ID | GPU | MEM |
# ------------------
# |  0 | 34% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9725 - accuracy: 0.6281 - top-3-accuracy: 0.9296 - val_loss: 1.4065 - val_accuracy: 0.6032 - val_top-3-accuracy: 0.9066
# Epoch 2/20
# 1796/3068 [================>.............] - ETA: 6s - loss: 0.9674 - accuracy: 0.6286 - top-3-accuracy: 0.9298| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9672 - accuracy: 0.6290 - top-3-accuracy: 0.9301 - val_loss: 1.3789 - val_accuracy: 0.6001 - val_top-3-accuracy: 0.9066
# Epoch 3/20
#  376/3068 [==>...........................] - ETA: 14s - loss: 0.9695 - accuracy: 0.6298 - top-3-accuracy: 0.9311| ID | GPU | MEM |
# ------------------
# |  0 | 47% | 37% |
# 2206/3068 [====================>.........] - ETA: 4s - loss: 0.9639 - accuracy: 0.6295 - top-3-accuracy: 0.9304| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9634 - accuracy: 0.6296 - top-3-accuracy: 0.9305 - val_loss: 1.3761 - val_accuracy: 0.6042 - val_top-3-accuracy: 0.9072
# Epoch 4/20
#  797/3068 [======>.......................] - ETA: 12s - loss: 0.9556 - accuracy: 0.6299 - top-3-accuracy: 0.9317| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 2631/3068 [========================>.....] - ETA: 2s - loss: 0.9597 - accuracy: 0.6304 - top-3-accuracy: 0.9308| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9598 - accuracy: 0.6306 - top-3-accuracy: 0.9310 - val_loss: 1.3711 - val_accuracy: 0.6035 - val_top-3-accuracy: 0.9076
# Epoch 5/20
# 1226/3068 [==========>...................] - ETA: 10s - loss: 0.9568 - accuracy: 0.6310 - top-3-accuracy: 0.9314| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 3057/3068 [============================>.] - ETA: 0s - loss: 0.9567 - accuracy: 0.6313 - top-3-accuracy: 0.9314| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9566 - accuracy: 0.6313 - top-3-accuracy: 0.9314 - val_loss: 1.3701 - val_accuracy: 0.6053 - val_top-3-accuracy: 0.9088
# Epoch 6/20
# 1643/3068 [===============>..............] - ETA: 7s - loss: 0.9549 - accuracy: 0.6320 - top-3-accuracy: 0.9319| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9534 - accuracy: 0.6321 - top-3-accuracy: 0.9319 - val_loss: 1.3466 - val_accuracy: 0.6054 - val_top-3-accuracy: 0.9089
# Epoch 7/20
#  215/3068 [=>............................] - ETA: 16s - loss: 0.9532 - accuracy: 0.6318 - top-3-accuracy: 0.9323| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 2017/3068 [==================>...........] - ETA: 5s - loss: 0.9509 - accuracy: 0.6327 - top-3-accuracy: 0.9323| ID | GPU | MEM |
# ------------------
# |  0 | 47% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9508 - accuracy: 0.6327 - top-3-accuracy: 0.9322 - val_loss: 1.3468 - val_accuracy: 0.6053 - val_top-3-accuracy: 0.9091
# Epoch 8/20
#  576/3068 [====>.........................] - ETA: 13s - loss: 0.9456 - accuracy: 0.6338 - top-3-accuracy: 0.9328| ID | GPU | MEM |
# ------------------
# |  0 | 47% | 37% |
# 2373/3068 [======================>.......] - ETA: 3s - loss: 0.9484 - accuracy: 0.6327 - top-3-accuracy: 0.9325| ID | GPU | MEM |
# ------------------
# |  0 | 47% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9483 - accuracy: 0.6332 - top-3-accuracy: 0.9326 - val_loss: 1.3457 - val_accuracy: 0.6071 - val_top-3-accuracy: 0.9096
# Epoch 9/20
#  965/3068 [========>.....................] - ETA: 11s - loss: 0.9465 - accuracy: 0.6345 - top-3-accuracy: 0.9333| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 2799/3068 [==========================>...] - ETA: 1s - loss: 0.9455 - accuracy: 0.6340 - top-3-accuracy: 0.9330| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9456 - accuracy: 0.6341 - top-3-accuracy: 0.9329 - val_loss: 1.3452 - val_accuracy: 0.6070 - val_top-3-accuracy: 0.9101
# Epoch 10/20
# 1378/3068 [============>.................] - ETA: 9s - loss: 0.9422 - accuracy: 0.6352 - top-3-accuracy: 0.9334| ID | GPU | MEM |
# ------------------
# |  0 | 47% | 37% |
# 3066/3068 [============================>.] - ETA: 0s - loss: 0.9433 - accuracy: 0.6348 - top-3-accuracy: 0.9333| ID | GPU | MEM |
# ------------------
# |  0 | 34% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9433 - accuracy: 0.6348 - top-3-accuracy: 0.9333 - val_loss: 1.3393 - val_accuracy: 0.6075 - val_top-3-accuracy: 0.9103
# Epoch 11/20
# 1789/3068 [================>.............] - ETA: 7s - loss: 0.9418 - accuracy: 0.6353 - top-3-accuracy: 0.9336| ID | GPU | MEM |
# ------------------
# |  0 | 47% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9407 - accuracy: 0.6356 - top-3-accuracy: 0.9337 - val_loss: 1.3385 - val_accuracy: 0.6079 - val_top-3-accuracy: 0.9106
# Epoch 12/20
#  372/3068 [==>...........................] - ETA: 14s - loss: 0.9387 - accuracy: 0.6381 - top-3-accuracy: 0.9334| ID | GPU | MEM |
# ------------------
# |  0 | 46% | 37% |
# 2175/3068 [====================>.........] - ETA: 4s - loss: 0.9388 - accuracy: 0.6360 - top-3-accuracy: 0.9341| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9385 - accuracy: 0.6361 - top-3-accuracy: 0.9340 - val_loss: 1.3316 - val_accuracy: 0.6081 - val_top-3-accuracy: 0.9114
# Epoch 13/20
#  750/3068 [======>.......................] - ETA: 12s - loss: 0.9387 - accuracy: 0.6361 - top-3-accuracy: 0.9338| ID | GPU | MEM |
# ------------------
# |  0 | 47% | 37% |
# 2553/3068 [=======================>......] - ETA: 2s - loss: 0.9368 - accuracy: 0.6368 - top-3-accuracy: 0.9342| ID | GPU | MEM |
# ------------------
# |  0 | 46% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9363 - accuracy: 0.6368 - top-3-accuracy: 0.9342 - val_loss: 1.3303 - val_accuracy: 0.6118 - val_top-3-accuracy: 0.9118
# Epoch 14/20
# 1145/3068 [==========>...................] - ETA: 10s - loss: 0.9349 - accuracy: 0.6362 - top-3-accuracy: 0.9345| ID | GPU | MEM |
# ------------------
# |  0 | 47% | 37% |
# 2975/3068 [============================>.] - ETA: 0s - loss: 0.9343 - accuracy: 0.6373 - top-3-accuracy: 0.9346| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9342 - accuracy: 0.6373 - top-3-accuracy: 0.9345 - val_loss: 1.3250 - val_accuracy: 0.6114 - val_top-3-accuracy: 0.9120
# Epoch 15/20
# 1556/3068 [==============>...............] - ETA: 8s - loss: 0.9324 - accuracy: 0.6376 - top-3-accuracy: 0.9345| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9321 - accuracy: 0.6381 - top-3-accuracy: 0.9348 - val_loss: 1.3191 - val_accuracy: 0.6135 - val_top-3-accuracy: 0.9126
# Epoch 16/20
#  124/3068 [>.............................] - ETA: 16s - loss: 0.9275 - accuracy: 0.6386 - top-3-accuracy: 0.9353| ID | GPU | MEM |
# ------------------
# |  0 | 44% | 37% |
# 1955/3068 [==================>...........] - ETA: 6s - loss: 0.9316 - accuracy: 0.6384 - top-3-accuracy: 0.9349| ID | GPU | MEM |
# ------------------
# |  0 | 47% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9300 - accuracy: 0.6385 - top-3-accuracy: 0.9350 - val_loss: 1.3144 - val_accuracy: 0.6109 - val_top-3-accuracy: 0.9123
# Epoch 17/20
#  530/3068 [====>.........................] - ETA: 13s - loss: 0.9272 - accuracy: 0.6387 - top-3-accuracy: 0.9354| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 2350/3068 [=====================>........] - ETA: 3s - loss: 0.9279 - accuracy: 0.6393 - top-3-accuracy: 0.9354| ID | GPU | MEM |
# ------------------
# |  0 | 46% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9281 - accuracy: 0.6393 - top-3-accuracy: 0.9354 - val_loss: 1.3148 - val_accuracy: 0.6140 - val_top-3-accuracy: 0.9133
# Epoch 18/20
#  915/3068 [=======>......................] - ETA: 11s - loss: 0.9257 - accuracy: 0.6394 - top-3-accuracy: 0.9355| ID | GPU | MEM |
# ------------------
# |  0 | 47% | 37% |
# 2735/3068 [=========================>....] - ETA: 1s - loss: 0.9265 - accuracy: 0.6396 - top-3-accuracy: 0.9357| ID | GPU | MEM |
# ------------------
# |  0 | 47% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9262 - accuracy: 0.6397 - top-3-accuracy: 0.9357 - val_loss: 1.3309 - val_accuracy: 0.6140 - val_top-3-accuracy: 0.9133
# Epoch 19/20
# 1312/3068 [===========>..................] - ETA: 9s - loss: 0.9245 - accuracy: 0.6406 - top-3-accuracy: 0.9357| ID | GPU | MEM |
# ------------------
# |  0 | 47% | 37% |
# 3061/3068 [============================>.] - ETA: 0s - loss: 0.9244 - accuracy: 0.6405 - top-3-accuracy: 0.9360| ID | GPU | MEM |
# ------------------
# |  0 | 34% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9244 - accuracy: 0.6405 - top-3-accuracy: 0.9360 - val_loss: 1.3395 - val_accuracy: 0.6132 - val_top-3-accuracy: 0.9128
# Epoch 20/20
# 1705/3068 [===============>..............] - ETA: 7s - loss: 0.9231 - accuracy: 0.6402 - top-3-accuracy: 0.9362| ID | GPU | MEM |
# ------------------
# |  0 | 48% | 37% |
# 3068/3068 [==============================] - 18s 6ms/step - loss: 0.9225 - accuracy: 0.6411 - top-3-accuracy: 0.9363 - val_loss: 1.3370 - val_accuracy: 0.6137 - val_top-3-accuracy: 0.9141
# Training End time:11_March_22_1632
# Training start time:11_March_22_1632
# | ID | GPU | MEM |
# ------------------
# |  0 | 34% | 37% |
# Epoch 1/20
# 1321/1534 [========================>.....] - ETA: 1s - loss: 0.9178 - accuracy: 0.6423 - top-3-accuracy: 0.9369| ID | GPU | MEM |
# ------------------
# |  0 | 53% | 37% |
# 1534/1534 [==============================] - 11s 7ms/step - loss: 0.9185 - accuracy: 0.6424 - top-3-accuracy: 0.9369 - val_loss: 1.3053 - val_accuracy: 0.6153 - val_top-3-accuracy: 0.9142
# Epoch 2/20
# 1218/1534 [======================>.......] - ETA: 1s - loss: 0.9164 - accuracy: 0.6426 - top-3-accuracy: 0.9371| ID | GPU | MEM |
# ------------------
# |  0 | 54% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9168 - accuracy: 0.6428 - top-3-accuracy: 0.9371 - val_loss: 1.2969 - val_accuracy: 0.6150 - val_top-3-accuracy: 0.9142
# Epoch 3/20
# 1163/1534 [=====================>........] - ETA: 2s - loss: 0.9152 - accuracy: 0.6430 - top-3-accuracy: 0.9373| ID | GPU | MEM |
# ------------------
# |  0 | 50% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9155 - accuracy: 0.6432 - top-3-accuracy: 0.9372 - val_loss: 1.2992 - val_accuracy: 0.6162 - val_top-3-accuracy: 0.9145
# Epoch 4/20
# 1117/1534 [====================>.........] - ETA: 2s - loss: 0.9147 - accuracy: 0.6437 - top-3-accuracy: 0.9374| ID | GPU | MEM |
# ------------------
# |  0 | 53% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9140 - accuracy: 0.6440 - top-3-accuracy: 0.9374 - val_loss: 1.3023 - val_accuracy: 0.6175 - val_top-3-accuracy: 0.9149
# Epoch 5/20
# 1066/1534 [===================>..........] - ETA: 2s - loss: 0.9131 - accuracy: 0.6445 - top-3-accuracy: 0.9376| ID | GPU | MEM |
# ------------------
# |  0 | 53% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9126 - accuracy: 0.6443 - top-3-accuracy: 0.9377 - val_loss: 1.2835 - val_accuracy: 0.6179 - val_top-3-accuracy: 0.9160
# Epoch 6/20
# 1009/1534 [==================>...........] - ETA: 3s - loss: 0.9117 - accuracy: 0.6448 - top-3-accuracy: 0.9379| ID | GPU | MEM |
# ------------------
# |  0 | 53% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9113 - accuracy: 0.6446 - top-3-accuracy: 0.9378 - val_loss: 1.2926 - val_accuracy: 0.6170 - val_top-3-accuracy: 0.9155
# Epoch 7/20
#  953/1534 [=================>............] - ETA: 3s - loss: 0.9105 - accuracy: 0.6450 - top-3-accuracy: 0.9379| ID | GPU | MEM |
# ------------------
# |  0 | 53% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9099 - accuracy: 0.6451 - top-3-accuracy: 0.9380 - val_loss: 1.2957 - val_accuracy: 0.6178 - val_top-3-accuracy: 0.9155
# Epoch 8/20
#  894/1534 [================>.............] - ETA: 4s - loss: 0.9099 - accuracy: 0.6451 - top-3-accuracy: 0.9383| ID | GPU | MEM |
# ------------------
# |  0 | 53% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9087 - accuracy: 0.6455 - top-3-accuracy: 0.9382 - val_loss: 1.2978 - val_accuracy: 0.6180 - val_top-3-accuracy: 0.9151
# Epoch 9/20
#  830/1534 [===============>..............] - ETA: 4s - loss: 0.9106 - accuracy: 0.6451 - top-3-accuracy: 0.9379| ID | GPU | MEM |
# ------------------
# |  0 | 53% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9073 - accuracy: 0.6461 - top-3-accuracy: 0.9384 - val_loss: 1.3092 - val_accuracy: 0.6175 - val_top-3-accuracy: 0.9159
# Epoch 10/20
#  772/1534 [==============>...............] - ETA: 4s - loss: 0.9057 - accuracy: 0.6466 - top-3-accuracy: 0.9384| ID | GPU | MEM |
# ------------------
# |  0 | 53% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9062 - accuracy: 0.6465 - top-3-accuracy: 0.9386 - val_loss: 1.2963 - val_accuracy: 0.6176 - val_top-3-accuracy: 0.9159
# Epoch 11/20
#  716/1534 [=============>................] - ETA: 5s - loss: 0.9058 - accuracy: 0.6471 - top-3-accuracy: 0.9385| ID | GPU | MEM |
# ------------------
# |  0 | 54% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9050 - accuracy: 0.6468 - top-3-accuracy: 0.9387 - val_loss: 1.2841 - val_accuracy: 0.6209 - val_top-3-accuracy: 0.9161
# Epoch 12/20
#  674/1534 [============>.................] - ETA: 5s - loss: 0.9045 - accuracy: 0.6471 - top-3-accuracy: 0.9387| ID | GPU | MEM |
# ------------------
# |  0 | 53% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9038 - accuracy: 0.6474 - top-3-accuracy: 0.9389 - val_loss: 1.2879 - val_accuracy: 0.6205 - val_top-3-accuracy: 0.9168
# Epoch 13/20
#  620/1534 [===========>..................] - ETA: 5s - loss: 0.9036 - accuracy: 0.6470 - top-3-accuracy: 0.9389| ID | GPU | MEM |
# ------------------
# |  0 | 54% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9025 - accuracy: 0.6474 - top-3-accuracy: 0.9391 - val_loss: 1.2807 - val_accuracy: 0.6198 - val_top-3-accuracy: 0.9168
# Epoch 14/20
#  574/1534 [==========>...................] - ETA: 6s - loss: 0.9020 - accuracy: 0.6474 - top-3-accuracy: 0.9388| ID | GPU | MEM |
# ------------------
# |  0 | 53% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9015 - accuracy: 0.6478 - top-3-accuracy: 0.9392 - val_loss: 1.2923 - val_accuracy: 0.6198 - val_top-3-accuracy: 0.9171
# Epoch 15/20
#  523/1534 [=========>....................] - ETA: 6s - loss: 0.9021 - accuracy: 0.6474 - top-3-accuracy: 0.9394| ID | GPU | MEM |
# ------------------
# |  0 | 54% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.9001 - accuracy: 0.6484 - top-3-accuracy: 0.9394 - val_loss: 1.2810 - val_accuracy: 0.6202 - val_top-3-accuracy: 0.9177
# Epoch 16/20
#  467/1534 [========>.....................] - ETA: 6s - loss: 0.8972 - accuracy: 0.6490 - top-3-accuracy: 0.9392- ETA: 7s - loss: 0.8958 - accuracy: 0.6494 - top-3-accurac| ID | GPU | MEM |
# ------------------
# |  0 | 54% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.8990 - accuracy: 0.6488 - top-3-accuracy: 0.9396 - val_loss: 1.2837 - val_accuracy: 0.6197 - val_top-3-accuracy: 0.9174
# Epoch 17/20
#  412/1534 [=======>......................] - ETA: 7s - loss: 0.9009 - accuracy: 0.6492 - top-3-accuracy: 0.9398| ID | GPU | MEM |
# ------------------
# |  0 | 53% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.8978 - accuracy: 0.6488 - top-3-accuracy: 0.9399 - val_loss: 1.2849 - val_accuracy: 0.6207 - val_top-3-accuracy: 0.9176
# Epoch 18/20
#  375/1534 [======>.......................] - ETA: 7s - loss: 0.9011 - accuracy: 0.6492 - top-3-accuracy: 0.9397| ID | GPU | MEM |
# ------------------
# |  0 | 54% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.8968 - accuracy: 0.6496 - top-3-accuracy: 0.9399 - val_loss: 1.2823 - val_accuracy: 0.6209 - val_top-3-accuracy: 0.9170
# Epoch 19/20
#  335/1534 [=====>........................] - ETA: 7s - loss: 0.8959 - accuracy: 0.6496 - top-3-accuracy: 0.9399| ID | GPU | MEM |
# ------------------
# |  0 | 54% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.8957 - accuracy: 0.6496 - top-3-accuracy: 0.9401 - val_loss: 1.2919 - val_accuracy: 0.6178 - val_top-3-accuracy: 0.9172
# Epoch 20/20
#  287/1534 [====>.........................] - ETA: 7s - loss: 0.8939 - accuracy: 0.6506 - top-3-accuracy: 0.9403| ID | GPU | MEM |
# ------------------
# |  0 | 54% | 37% |
# 1534/1534 [==============================] - 10s 7ms/step - loss: 0.8947 - accuracy: 0.6503 - top-3-accuracy: 0.9402 - val_loss: 1.2810 - val_accuracy: 0.6218 - val_top-3-accuracy: 0.9176
# Training End time:11_March_22_1635

# %%
tf.keras.backend.clear_session()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 73% |
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 73% |
